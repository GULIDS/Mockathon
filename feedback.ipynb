# %%
#importing the required libraries
import pandas
import json
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
#turning off the distracting warnings in jupyter
import warnings
warnings.filterwarnings('ignore')

# %%
#importing the data needed
data=pandas.read_excel('feedback2.xlsx')

# %%
data.rename(columns = {'department2':'Stream'}, inplace = True)

# %%
data
# Out:
#          Sno                                            College  \
# 0       1114  avs college of engineering and technology - ne...
# 1       5187  k.l.s. gogte institute of technology - belgaum...
# 2       7351                manipal academy of higher education
# 3       9063  rajalakshmi engineering college - kanchipuram ...
# 4       9064  rajalakshmi engineering college - kanchipuram ...
# ...      ...                                                ...
# 17312   1839  brindavan college of engineering - bangalore -...
# 17313   1864  brindavan college of engineering - bangalore -...
# 17314  11541        sri ramakrishna college of arts and science
# 17315   1844  brindavan college of engineering - bangalore -...
# 17316    611  annapoorna institute of management and researc...
#
#                 State        Stream        rollno
# 0      Andhra Pradesh  Aeronautical   10532068404
# 1           Karnataka  Aeronautical    2GI19AE036
# 2           Karnataka  Aeronautical     190933156
# 3          Tamil Nadu  Aeronautical     190101005
# 4          Tamil Nadu  Aeronautical     190101028
# ...               ...           ...           ...
# 17312       Karnataka           NaN  P18BR21M0047
# 17313       Karnataka           NaN    P18R210056
# 17314      Tamil Nadu           NaN      20120004
# 17315       Karnataka           NaN  P18BR21M0055
# 17316       Karnataka           NaN  P15CI21M0007
#
# [17317 rows x 5 columns]

# %%
#Plot based on the state they are studying in
sns.set(rc={'figure.figsize':(20,20)})
sns.histplot(data=data['State']).set_xticklabels(rotation=90,labels=data['State'].unique())
# Out:
# [Text(0, 0, 'Andhra Pradesh'),
#  Text(1, 0, 'Karnataka'),
#  Text(2, 0, 'Tamil Nadu'),
#  Text(3, 0, 'Madhya Pradesh'),
#  Text(4, 0, 'Maharashtra'),
#  Text(5, 0, 'Odisha'),
#  Text(6, 0, 'West Bengal'),
#  Text(7, 0, 'Gujarat'),
#  Text(8, 0, 'Kerala'),
#  Text(9, 0, 'Uttarakhand'),
#  Text(10, 0, 'Uttar Pradesh'),
#  Text(11, 0, 'Telangana'),
#  Text(12, 0, 'Delhi'),
#  Text(13, 0, 'Assam'),
#  Text(14, 0, 'Punjab'),
#  Text(15, 0, 'Sikkim'),
#  Text(16, 0, 'Rajahsthan'),
#  Text(17, 0, 'Haryana'),
#  Text(18, 0, 'Jharkhand'),
#  Text(19, 0, 'Chhattisgarh'),
#  Text(20, 0, 'Jammu & Kashmir'),
#  Text(21, 0, 'Puducherry'),
#  Text(22, 0, 'Bihar'),
#  Text(23, 0, 'Himachal Pradesh'),
#  Text(24, 0, 'Orissa'),
#  Text(25, 0, 'Rajasthan'),
#  Text(26, 0, 'Goa')]

# %%
#Plot based on their background
sns.histplot(data=data['Stream']).set_xticklabels(rotation=90,labels=data['Stream'].unique())
# Out:
# [Text(0, 0, 'Aeronautical'),
#  Text(1, 0, 'Aerospace'),
#  Text(2, 0, 'Agriculture'),
#  Text(3, 0, 'Architecture'),
#  Text(4, 0, 'Automobile'),
#  Text(5, 0, 'Banking & Financial Services'),
#  Text(6, 0, 'Bio Engineering'),
#  Text(7, 0, 'Biology'),
#  Text(8, 0, 'Biomedical'),
#  Text(9, 0, 'Biotechnology'),
#  Text(10, 0, 'Botany'),
#  Text(11, 0, 'Business'),
#  Text(12, 0, 'Chemical'),
#  Text(13, 0, 'Civil'),
#  Text(14, 0, 'Commerce'),
#  Text(15, 0, 'Computer And Communication Engineering'),
#  Text(16, 0, 'Computer Application'),
#  Text(17, 0, 'Computer Science'),
#  Text(18, 0, 'Cryogenic Engineering'),
#  Text(19, 0, 'Dairy'),
#  Text(20, 0, 'Earth sciences'),
#  Text(21, 0, 'Economics'),
#  Text(22, 0, 'Electrical'),
#  Text(23, 0, 'Electronics'),
#  Text(24, 0, 'English Literature'),
#  Text(25, 0, 'Environmental Engineering'),
#  Text(26, 0, 'Farm'),
#  Text(27, 0, 'Fashion design'),
#  Text(28, 0, 'Fibres And Textiles Processing Technology'),
#  Text(29, 0, 'Finance'),
#  Text(30, 0, 'Food Engineering'),
#  Text(31, 0, 'Geography'),
#  Text(32, 0, 'Geology'),
#  Text(33, 0, 'Geophysics'),
#  Text(34, 0, 'Humanities & Social Sciences'),
#  Text(35, 0, 'Industrial Engineering'),
#  Text(36, 0, 'Infrastructure'),
#  Text(37, 0, 'Law'),
#  Text(38, 0, 'Management'),
#  Text(39, 0, 'Marine'),
#  Text(40, 0, 'Marketing'),
#  Text(41, 0, 'Mathematics'),
#  Text(42, 0, 'Mathematics, Physics, Computer Science'),
#  Text(43, 0, 'Mathematics, Statistics, and Computer Science'),
#  Text(44, 0, 'Mechanical'),
#  Text(45, 0, 'Media'),
#  Text(46, 0, 'Medical'),
#  Text(47, 0, 'Mining'),
#  Text(48, 0, 'Nano Technology'),
#  Text(49, 0, 'Nursing'),
#  Text(50, 0, 'Packaging'),
#  Text(51, 0, 'Petrochemical'),
#  Text(52, 0, 'Petrolium'),
#  Text(53, 0, 'Pharmacy'),
#  Text(54, 0, 'Physics'),
#  Text(55, 0, 'Planning'),
#  Text(56, 0, 'Polymer'),
#  Text(57, 0, 'Printing'),
#  Text(58, 0, 'Production'),
#  Text(59, 0, 'Robotics'),
#  Text(60, 0, 'Rubber'),
#  Text(61, 0, 'Rural'),
#  Text(62, 0, 'Safety And Fire Engineering'),
#  Text(63, 0, 'Safety, Health and Environment'),
#  Text(64, 0, 'Statistics'),
#  Text(65, 0, 'Structural'),
#  Text(66, 0, 'Textile'),
#  Text(67, 0, 'Training & Placement')]
