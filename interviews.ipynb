# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('interview.xlsx')

# %%
data2=data.copy()
data2=data2.replace(0,np.NaN)

# %%
avg_list=["speed",
"fluency",
"writing",
"speaking",
"listening",
"intonation",
"comprehension",
"pronunciation",
"spoken-grammar",
"written-grammar",
"domain-knowledge",
"spoken-word-quality",
"written-word-quality",
"spoken-sentence-quality",
"written-sentence-quality",
"domain-specific-terminologies"]

# %%
sns.set(rc={'figure.figsize':(10,10)})

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(data2[avg_list].corr(),cbar=True,linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data2[avg_list]).set_xticklabels(rotation=90,labels=avg_list)
# Out:
# [Text(0, 0, 'speed'),
#  Text(1, 0, 'fluency'),
#  Text(2, 0, 'writing'),
#  Text(3, 0, 'speaking'),
#  Text(4, 0, 'listening'),
#  Text(5, 0, 'intonation'),
#  Text(6, 0, 'comprehension'),
#  Text(7, 0, 'pronunciation'),
#  Text(8, 0, 'spoken-grammar'),
#  Text(9, 0, 'written-grammar'),
#  Text(10, 0, 'domain-knowledge'),
#  Text(11, 0, 'spoken-word-quality'),
#  Text(12, 0, 'written-word-quality'),
#  Text(13, 0, 'spoken-sentence-quality'),
#  Text(14, 0, 'written-sentence-quality'),
#  Text(15, 0, 'domain-specific-terminologies')]
